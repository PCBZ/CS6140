# %% [markdown]
# <a href="https://colab.research.google.com/github/PCBZ/CS6140/blob/main/HW5/HW5_problem2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ucimlrepo

from ucimlrepo import fetch_ucirepo
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

import numpy as np

class LinearSVM:
    """
    SVM implementation using Sequential Minimal Optimization (SMO) algorithm
    """
    def __init__(self, C=1.0, tol=1e-3, max_pass=200):
        """
        Initialize SVM with Linear Kernel

        Parameters
        ----------
        C : float, optional (default=1.0)
            Penalty parameter C of the error term.
        tol : float, optional (default=1e-3)
            Tolerance for stopping criteria.
        max_pass : int, optional (default=5)
            Maximum number of passes through the training data.
        """
        self.C = C
        self.tol = tol
        self.max_pass = max_pass

        self.alphas = None
        self.bias = 0
        self.X = None
        self.y = None
        self.num_samples = 0
        self.num_features = 0
        self.error_cache = {}

    def kernel_function(self, x1, x2):
        """
        Compute the linear kernel between two vectors.
        """
        return x1 @ x2

    def compute_kernel_matrix(self, X1, X2=None):
        """
        Compute the kernel matrix for a given set of vectors.
        """
        if X2 is None:
            X2 = X1
        m = X1.shape[0]
        n = X2.shape[0]
        K = np.zeros((m, n))
        for i in range(m):
            for j in range(n):
                K[i, j] = self.kernel_function(X1[i], X2[j])
        return K

    def predict_single(self, x):
        """
        Predict the label of a single vector.
        """
        prediction = self.bias
        for i in range(self.num_samples):
            if self.alphas[i] > 0:
                prediction += self.alphas[i] * self.y[i] * self.kernel_function(self.X[i], x)
        return prediction

    def get_error(self, i):
        """
        Compute the error of a single vector.
        """
        return self.predict_single(self.X[i]) - self.y[i]

    def select_second_alpha(self, first_idx, first_error):
        """
        Select the second alpha to optimize.
        """
        return (first_idx + 1) % self.num_samples


    def optimize_alpha_pair(self, first_idx, second_idx):
        """
        Optimize alpha pair using SMO algorithm
        """
        if first_idx == second_idx:
            return 0
        alpha1 = self.alphas[first_idx]
        alpha2 = self.alphas[second_idx]
        y1 = self.y[first_idx]
        y2 = self.y[second_idx]

        error1 = self.get_error(first_idx)
        error2 = self.get_error(second_idx)

        if y1 != y2:
            L = max(0, alpha2 - alpha1)
            H = min(self.C, self.C + alpha2 - alpha1)
        else:
            L = max(0, alpha1 + alpha2 - self.C)
            H = min(self.C, alpha1 + alpha2)
        if L == H:
            return 0

        kernel11 = self.kernel_function(self.X[first_idx], self.X[first_idx])
        kernel22 = self.kernel_function(self.X[second_idx], self.X[second_idx])
        kernel12 = self.kernel_function(self.X[first_idx], self.X[second_idx])

        eta = kernel11 + kernel22 - 2 * kernel12

        if eta > 0:
            alpha2_new = alpha2 + y2 * (error1 - error2) / eta
            alpha2_new = np.clip(alpha2_new, L, H)
        else:
            return 0

        if np.abs(alpha2_new - alpha2) < self.tol:
            return 0

        alpha1_new = alpha1 + y1 * y2 * (alpha2 - alpha2_new)

        self.alphas[first_idx] = alpha1_new
        self.alphas[second_idx] = alpha2_new

        bias1 = self.bias - error1 - y1 * (alpha1_new - alpha1) * kernel11 - y2 * (alpha2_new - alpha2) * kernel12
        bias2 = self.bias - error2 - y1 * (alpha1_new - alpha1) * kernel12 - y2 * (alpha2_new - alpha2) * kernel22

        if 0 < alpha1_new < self.C:
            self.bias = bias1
        elif 0 < alpha2_new < self.C:
            self.bias = bias2
        else:
            self.bias = (bias1 + bias2) / 2

        return 1

    def examine_sample(self, sample_idx):
        y = self.y[sample_idx]
        alpha = self.alphas[sample_idx]
        error = self.get_error(sample_idx)

        if ((y * error < -self.tol and alpha < self.C) or (y * error > self.tol and alpha > 0)):

            second_idx = self.select_second_alpha(sample_idx, error)

            if self.optimize_alpha_pair(sample_idx, second_idx):
                return 1

        return 0

    def fit(self, X, y):
        """
        Train the SVM model to the training data.
        """
        self.X = X.copy()
        self.y = y.copy()
        self.num_samples, self.num_features = X.shape
        self.alphas = np.zeros(self.num_samples)
        self.bias = 0

        num_passes = 0

        while num_passes < self.max_pass:
            num_changed = 0

            for i in range(self.num_samples):
                num_changed += self.examine_sample(i)

            if num_changed == 0:
                break
            else:
                num_passes += 1

            print(f"Pass {num_passes}: {num_changed} alphas changed")

        num_support_vectors = np.sum(self.alphas > 1e-5)
        print(f"Training completed after {num_passes} passes")
        print(f"Number of support vectors: {num_support_vectors}")

    def predict(self, X):
        """
        Predict the labels of the input data.
        """
        predictions = np.zeros(X.shape[0])
        for i in range(X.shape[0]):
            predictions[i] = self.predict_single(X[i])
        return np.sign(predictions)


def fetch_spambase_data():
    """
    Fetch Spambase dataset from UCI repository
    """
    spambase = fetch_ucirepo(id=94)

    # Extract features and targets
    X = spambase.data.features.values
    y = spambase.data.targets.values.ravel()

    return X, y

def preprocess_data(X, y):
    """
    Preprocess the data
    """
    # Covert labels to 1/-1
    y = np.where(y == 0, -1, 1)

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    # Standardization
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    return X_train, X_test, y_train, y_test

def train_and_evaluate_svm_model(X_train, y_train, X_test, y_test):
    """
    Train and evaluate SVM model
    """
    model = LinearSVM(C=2.0, tol=0.005, max_pass=200)
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    print(f"Train Accuracy: {train_accuracy}")
    print(f"Test Accuracy: {test_accuracy}")


if __name__ == "__main__":
    X, y = fetch_spambase_data()
    X_train, X_test, y_train, y_test = preprocess_data(X, y)
    train_and_evaluate_svm_model(X_train, y_train, X_test, y_test)
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.11/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.7.14)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Pass 1: 173 alphas changed
# Pass 2: 212 alphas changed
# Pass 3: 184 alphas changed
# Pass 4: 177 alphas changed
# Pass 5: 168 alphas changed
# Pass 6: 165 alphas changed
# Pass 7: 159 alphas changed
# Pass 8: 159 alphas changed
# Pass 9: 155 alphas changed
# Pass 10: 150 alphas changed
# Pass 11: 146 alphas changed
# Pass 12: 145 alphas changed
# Pass 13: 139 alphas changed
# Pass 14: 140 alphas changed
# Pass 15: 144 alphas changed
# Pass 16: 140 alphas changed
# Pass 17: 143 alphas changed
# Pass 18: 146 alphas changed
# Pass 19: 144 alphas changed
# Pass 20: 149 alphas changed
# Pass 21: 138 alphas changed
# Pass 22: 137 alphas changed
# Pass 23: 131 alphas changed
# Pass 24: 134 alphas changed
# Pass 25: 127 alphas changed
# Pass 26: 133 alphas changed
# Pass 27: 128 alphas changed
# Pass 28: 123 alphas changed
# Pass 29: 119 alphas changed
# Pass 30: 124 alphas changed
# Pass 31: 122 alphas changed
# Pass 32: 130 alphas changed
# Pass 33: 128 alphas changed
# Pass 34: 126 alphas changed
# Pass 35: 120 alphas changed
# Pass 36: 119 alphas changed
# Pass 37: 120 alphas changed
# Pass 38: 123 alphas changed
# Pass 39: 118 alphas changed
# Pass 40: 113 alphas changed
# Pass 41: 112 alphas changed
# Pass 42: 110 alphas changed
# Pass 43: 114 alphas changed
# Pass 44: 109 alphas changed
# Pass 45: 109 alphas changed
# Pass 46: 107 alphas changed
# Pass 47: 111 alphas changed
# Pass 48: 108 alphas changed
# Pass 49: 103 alphas changed
# Pass 50: 96 alphas changed
# Pass 51: 87 alphas changed
# Pass 52: 91 alphas changed
# Pass 53: 93 alphas changed
# Pass 54: 85 alphas changed
# Pass 55: 87 alphas changed
# Pass 56: 93 alphas changed
# Pass 57: 92 alphas changed
# Pass 58: 91 alphas changed
# Pass 59: 80 alphas changed
# Pass 60: 83 alphas changed
# Pass 61: 89 alphas changed
# Pass 62: 78 alphas changed
# Pass 63: 82 alphas changed
# Pass 64: 88 alphas changed
# Pass 65: 78 alphas changed
# Pass 66: 86 alphas changed
# Pass 67: 76 alphas changed
# Pass 68: 78 alphas changed
# Pass 69: 84 alphas changed
# Pass 70: 82 alphas changed
# Pass 71: 85 alphas changed
# Pass 72: 82 alphas changed
# Pass 73: 92 alphas changed
# Pass 74: 80 alphas changed
# Pass 75: 80 alphas changed
# Pass 76: 84 alphas changed
# Pass 77: 82 alphas changed
# Pass 78: 77 alphas changed
# Pass 79: 70 alphas changed
# Pass 80: 77 alphas changed
# Pass 81: 78 alphas changed
# Pass 82: 76 alphas changed
# Pass 83: 71 alphas changed
# Pass 84: 69 alphas changed
# Pass 85: 71 alphas changed
# Pass 86: 75 alphas changed
# Pass 87: 70 alphas changed
# Pass 88: 73 alphas changed
# Pass 89: 74 alphas changed
# Pass 90: 70 alphas changed
# Pass 91: 69 alphas changed
# Pass 92: 70 alphas changed
# Pass 93: 71 alphas changed
# Pass 94: 67 alphas changed
# Pass 95: 72 alphas changed
# Pass 96: 68 alphas changed
# Pass 97: 68 alphas changed
# Pass 98: 68 alphas changed
# Pass 99: 65 alphas changed
# Pass 100: 68 alphas changed
# Pass 101: 72 alphas changed
# Pass 102: 67 alphas changed
# Pass 103: 65 alphas changed
# Pass 104: 68 alphas changed
# Pass 105: 62 alphas changed
# Pass 106: 63 alphas changed
# Pass 107: 64 alphas changed
# Pass 108: 65 alphas changed
# Pass 109: 57 alphas changed
# Pass 110: 59 alphas changed
# Pass 111: 69 alphas changed
# Pass 112: 73 alphas changed
# Pass 113: 62 alphas changed
# Pass 114: 61 alphas changed
# Pass 115: 59 alphas changed
# Pass 116: 62 alphas changed
# Pass 117: 67 alphas changed
# Pass 118: 66 alphas changed
# Pass 119: 63 alphas changed
# Pass 120: 76 alphas changed
# Pass 121: 89 alphas changed
# Pass 122: 99 alphas changed
# Pass 123: 85 alphas changed
# Pass 124: 86 alphas changed
# Pass 125: 81 alphas changed
# Pass 126: 84 alphas changed
# Pass 127: 89 alphas changed
# Pass 128: 87 alphas changed
# Pass 129: 78 alphas changed
# Pass 130: 82 alphas changed
# Pass 131: 74 alphas changed
# Pass 132: 83 alphas changed
# Pass 133: 70 alphas changed
# Pass 134: 74 alphas changed
# Pass 135: 65 alphas changed
# Pass 136: 65 alphas changed
# Pass 137: 66 alphas changed
# Pass 138: 73 alphas changed
# Pass 139: 59 alphas changed
# Pass 140: 70 alphas changed
# Pass 141: 62 alphas changed
# Pass 142: 62 alphas changed
# Pass 143: 57 alphas changed
# Pass 144: 61 alphas changed
# Pass 145: 61 alphas changed
# Pass 146: 65 alphas changed
# Pass 147: 62 alphas changed
# Pass 148: 56 alphas changed
# Pass 149: 51 alphas changed
# Pass 150: 51 alphas changed
# Pass 151: 51 alphas changed
# Pass 152: 54 alphas changed
# Pass 153: 52 alphas changed
# Pass 154: 51 alphas changed
# Pass 155: 49 alphas changed
# Pass 156: 55 alphas changed
# Pass 157: 55 alphas changed
# Pass 158: 54 alphas changed
# Pass 159: 48 alphas changed
# Pass 160: 49 alphas changed
# Pass 161: 50 alphas changed
# Pass 162: 48 alphas changed
# Pass 163: 48 alphas changed
# Pass 164: 50 alphas changed
# Pass 165: 52 alphas changed
# Pass 166: 54 alphas changed
# Pass 167: 42 alphas changed
# Pass 168: 44 alphas changed
# Pass 169: 41 alphas changed
# Pass 170: 45 alphas changed
# Pass 171: 48 alphas changed
# Pass 172: 49 alphas changed
# Pass 173: 44 alphas changed
# Pass 174: 50 alphas changed
# Pass 175: 56 alphas changed
# Pass 176: 53 alphas changed
# Pass 177: 49 alphas changed
# Pass 178: 42 alphas changed
# Pass 179: 51 alphas changed
# Pass 180: 48 alphas changed
# Pass 181: 52 alphas changed
# Pass 182: 48 alphas changed
# Pass 183: 47 alphas changed
# Pass 184: 50 alphas changed
# Pass 185: 44 alphas changed
# Pass 186: 43 alphas changed
# Pass 187: 42 alphas changed
# Pass 188: 46 alphas changed
# Pass 189: 40 alphas changed
# Pass 190: 45 alphas changed
# Pass 191: 44 alphas changed
# Pass 192: 40 alphas changed
# Pass 193: 45 alphas changed
# Pass 194: 41 alphas changed
# Pass 195: 41 alphas changed
# Pass 196: 42 alphas changed
# Pass 197: 43 alphas changed
# Pass 198: 33 alphas changed
# Pass 199: 44 alphas changed
# Pass 200: 39 alphas changed
# Training completed after 200 passes
# Number of support vectors: 479
# Train Accuracy: 0.9263586956521739
# Test Accuracy: 0.9120521172638436
